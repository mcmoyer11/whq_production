# %% [markdown]
# # Refining the labels for Inclusory Heuristics
#
#
#
# ### The goal of this script is to take care of the following problems:
# 1. the strict_emb heuristic is grabbing root questions that appear in quotes

# %%
from __future__ import division
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl 
import numpy as np
import re
from nltk import word_tokenize
from nltk import pos_tag

# %% [markdown]
# ## Make sure to load in the dataset that was modified from the Exclusive heuristics notebook, because this notebook will output a new .json file for making graphs.

# %%
df = pd.read_json("edited_edited_corpus.json")

# %%
df['emb_verb'] = df['emb_verb'].replace({'Can': 'can', 'CAN': 'can', 'WILL': 'will', 'Will': 'will', 'Could': 'could', 'Would':'would', 'Should': 'should'})
df['v1_after'] = df['v1_after'].replace({'Can': 'can', 'CAN': 'can', 'WILL': 'will', 'Will': 'will', 'Could': 'could', 'Would':'would', 'Should': 'should'})

# %%
# This makes the display show more info
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', -1)

# %%
root = df[df.questType == "Root Question"]
emb = df[df.questType == "Embeded Question"]

# %% [markdown]
# ## A. Embedded Questions
# Break it up by heuristic.

# %%
emb.groupby(["heuristic"])["heuristic"].count()
# Out:
# heuristic
# second_pass    335
# strict_emb     35024
# v_before_wh    5135
# Name: heuristic, dtype: int64

# %%
emb_se = emb.loc[emb.heuristic.isin(["strict_emb"])]
emb_vbw = emb.loc[emb.heuristic.isin(["v_before_wh"])]
emb_sp = emb.loc[emb.heuristic.isin(["second_pass"])]

# %% [markdown]
# ### 1. Strict Emb

# %%
len(emb_se)
# Out:
# 34975

# %%
emb_se.groupby(["clauseType"])["clauseType"].count()
# Out:
# clauseType
# Finite        27886
# Modal         4174
# Non-Finite    2915
# Name: clauseType, dtype: int64

# %%
# emb_se.sentence

# %% [markdown]
# ### 2. v_before_wh

# %%
len(emb_vbw)
# Out:
# 5130

# %%
# uhoh, these have several root questions
# emb_vbw.sentence

# %%
emb_vbw_qmark = emb_vbw.loc[emb_vbw.sentence.str.contains("\?")]

# %%
# emb_vbw_qmark.sentence

# %%
len(emb_vbw_qmark)/len(emb_vbw)

# %%
emb_vbw_qmark_indexes = emb_vbw_qmark.index.values.tolist()

# %%
df.at[emb_vbw_qmark_indexes,'questType'] = 'Root Question'
df.at[emb_vbw_qmark_indexes,'mat_verb'] = None

# %% [markdown]
# ### 3. second pass
#
# These look like they should be gone through more closely.

# %%
len(emb_sp)
# Out:
# 333

# %%
emb_sp.sentence
# Out:
# 2110      By better understanding how the brain is altered with this syndrome , we can develop better drugs in the future ."
# 4543      But whatever is ultimately decided about where person, place and time deixis belong, there is little doubt that most aspects of discourse deixis and social deixis will lie outside the scope ofa truth-conditional semantics.
# 7042      But finally, erm how about his erm religious history?
# 9138      What's more, who'd have believed he'd picked her up in a wine bar ?
# 10641     over and see how much
# 11239     to review, and where appropriate to make recommendations to Government Departments concerned on, the advancement of the general purposes of the Order and the provision of information and advisory services;
# 14060     And look how white I am compared with you; your tan still hasn't faded completely.’
# 18369     And going out to where
# 18504     And in considering how such things could have fooled some of our most eminent Baroque scholars and performers, I leave the reader to judge whether the question mark in my title deserves to be there.
# 18658     But consider how the following additional constraints would make your task so much more difficult (and relate these constraints to the problems of being unable to study the SCN directly, of being unsure of exactly how it then sends its information to produce the rhythms in, say, temperature or urine flow — things that we can measure — and even of not being certain that the SCN is the only area in the brain that is part of the body clock).
# 20454     But, even knowing how strong the British now were, he would give up polo tomorrow and climb back into his cockpit and resume the attack on Port Stanley.
# 23498     And when (timing) and where (location)?
# 26731     Deciding what is to be done, and who is to carry out the tasks involved.
# 28342     And see how we get on that.
# 28587     And know how to deal with them.
# 29210     and see how you get on.
# 31480     Still, there was more to see, and who should I stumble upon next but those entertaining and talented Parliamentary opponents, Neil Kinnock and John Major…
# 31545     And see how, if that will work out any better.
# 31612     And look at how long it lasted as well.
# 33206     And know not how to act in this new Being.
# 38230     And so that shows that how that they  I mean it implies that that's happening and that that ought to be controlled.
# 38261     But  argues that how that in actual fact by this time land reform had already taken place and there wasn't enough, any more land to be redistributed.
# 39165     But to work out how successful a campaign has been, the retailer needs to balance the profit made against the amount of money he spent on the campaign.
# 45387     And — who knows?— Mach might even give the T'ang his father's ear back.’
# 45502     Would watch closely and see how matters developed.
# 46331     But by being ashamed of who they are, they're making it harder for other people to accept them.’
# 47390     But to see how false this justification, let us play the equality card.
# 49718     But, by understanding how he saw leys being constructed and operating, a picture begins to emerge of a system where each piece can be fitted into the whole.
# 50253     But growing up and learning how she ought to feel and behave, what she ought to value, means that she has to give  up doing just as she pleases.
# 51574     But see see where we go on that.
# 52256     And see how wide it can be and also in some respects how remote it can be.
# 52269     Depends what and how  this is where we get husband and wife survivorships.
# 54417     and see how it goes then .
# 59458     are greatest and where the greatest problem there are or, or, er exist under normal circumstances to which the trunk roads, the A roads, the primary roads, the principle roads, these roads are where the traffic is greatest and this therefore constitutes in my mind at least the most important roads, I think your correct term, we will er consider the phraseology used in perhaps more accurately to described the, the, the title road which we are talking about here, but I certainly take the point you make.
# 62300     Try and think how you would feel if that happened to you.
# 63800     At least that is how such works as the large reliefs by Nichola Burrell come across.
# 64163     But quite how high the criterion score needs to be in order to indicate mastery of a domain or readiness for further learning is not easily established- A very high cut-off score may fail pupils who have learned the material but have made slips.
# 65661     And  stood blocking like, how I get round to the till!
# 67742     and see how it's doing.
# 69053     down and worked out how many days he's had the long wheelbase this week.
# 71796     and didn't know where to find
# 71802     And didn't know where to find them, leave them alone and they will come home wagging their tails behind them
# 72837     But to show how willing I was, I sent the outline to Hugh Puddephat.
# 75170     By whom and how?’
# 76825     and, learning how to read
# 77798     Still, there are plenty more where they came from.
# ...
# 416425    and find out where this goes
# 417335    or go with out and say where say go with that and go where's the wine?
# 418056    down there or   is that where we went for a meal that time?
# 418223    and go through rather than how can you go around the man
# 418411    and are more how can I say? not so not so maybe not so corrupt I don't know but like everything changes
# 418536    but then that might be to do with how used to one is to  people swearing now you know like now it's common as muck but when I was young if you heard somebody say fuck it that was really shocking  I mean I personally think that Scheiße is stronger than shit
# 418744    and then yeah but then how d w how does the evening go? never quite worked that out
# 419602    and erm oh how's  I've forgotten how I do it now
# 420282    and disagree where is necessary we've got to go round and do that thoroughly then soon
# 420676    and work out how to improve how to beat somebody?
# 421125    and then  was like where were you? I was like well I didn't know where anybod I didn't know what the plan was so I just didn't come they were like and he was like oh
# 421152    but not really talk about how to avoid cancer it's just saying don't think about cancer but
# 424534    which is precisely what, and where, he is, and is the reason he walks in twos and threes.
# 425304    But consider also how much you and your family can keep up along with your other work.
# 425452    And then think how little hydrogen we have in us compared with the hydrogen in Delaware Bay or in the ocean beyond.
# Name: sentence, dtype: object

# %% [markdown]
# ### Summary
#
# Change the ones with '?' to Root question

# %%
# df.at[emb_vbw_qmark_indexes, 'questType'] = 'Root Question'

# %% [markdown]
# ## B. Root Questions

# %%
root.groupby(["heuristic"])["heuristic"].count()
# Out:
# heuristic
# ?              23219
# amb            3677
# frag           817
# second_pass    2
# strict_emb     49
# sub_aux_inv    6867
# v_before_wh    5
# Name: heuristic, dtype: int64

# %%
root.iloc[100]
# Out:
# corpus        bnc
# medium        print
# sentence      Where are we to account for the hints, implicit purposes, assumptions, social attitudes and so on that are effectively communicated by the use of language, not to mention the figures of speech (e.g. metaphor, irony, rhetorical questions, understatement) that have preoccupied theorists of rhetoric and literature?
# clauseType    Finite
# phrase
# wh            where
# questType     Root Question
# heuristic     ?
# v_before
# v1_after      are
# v2_after      account
# v3_after      are
# wh_v1         [[Where, WRB], [are, VBP]]
# mat_verb      None
# emb_verb      be
# Name: 4468, dtype: object

# %%
root_qmark = root.loc[root.heuristic.isin(["?"])]
root_sai = root.loc[root.heuristic.isin(["sub_aux_inv"])]

# %% [markdown]
# ## ?

# %%
len(root_qmark)
# Out:
# 23219

# %%
root_qmark.groupby(["clauseType"])["clauseType"].count()
# Out:
# clauseType
# Finite    18461
# Modal     4758
# Name: clauseType, dtype: int64

# %%
# root_qmark.sentence

# %% [markdown]
# ## Subject-Aux-Inversion

# %%
len(root_sai)
# Out:
# 6867

# %%
root_sai.groupby(["clauseType"])["clauseType"].count()
# Out:
# clauseType
# Finite    6649
# Modal     218
# Name: clauseType, dtype: int64

# %%
root_sai.sentence
# Out:
# 2319      How do aerosols influence ocean currents ?
# 2374      How did these cells evolve ?
# 2400      How did they do it ?
# 2636      Who's in it now?
# 3148      Where was it among the glitz of that infamous Sheffield rally?
# 3359      Where was Richard Tonks?
# 3360      Who is the new chairman?
# 3656      Where was she?
# 3672      Where was Maria?
# 3685      Where was she anyway?
# 4038      Who is this cayman, who never blinks?
# 4266      Where is their estate?’
# 4351      ‘How can an idea father a child?’
# 4587      How did you do it?
# 4651      Now, where was I?
# 4792      Who is the new Grand Old Man (or Woman) of English letters?
# 4794      Who is the new guv'nor?
# 4796      Who's king of the jungle, the lion or the elephant?
# 5285      Now  er who did it last year amongst you?
# 5320      Where is it?
# 5407      How is it that 80 per cent.
# 5432      Where is the honour?
# 6233      Where is the sense or comparability of that?
# 6397      Where is the uncertainty in that?
# 6500      Where is the evidence?
# 6969      Where is Adai now?
# 6996      Where was this from?
# 7204      Where was the bloody fish.
# 7786      Where was she?
# 7825      ‘How could you do that?
# 7884      where's Mike, oh you're there, Mike.
# 7891      How can we have any other bodies and blood than our own?
# 8222      Who was the burglar breaking in through an entryphone?
# 8225      Where does the Government stand on this?
# 8273      How do you  in the first place?
# 8325      ‘How do you do?
# 8352      Where was Amy now?
# 8861      How is it with you?
# 8891      Where and when do the Guides meet?
# 8894      Who Is Persephone?
# 8916      Here's how to do it.
# 9194      (How would my life change if I had a great deal of money?
# 9263      How do they do it?
# 9271      Where were they?
# 9272      Where were they?
# 9386      How's this for rhetoric?
# 9594      Who was on the form sub committee?
# 9636      How to do it.
# 9748      Who's on take today?’
# 9762      Where are these photos, then?’
# 9773      Where's your stuff?’
# 9787      Where's the bedroom?’
# 9797      How's the right radial pulse, Kath?’
# 9809      ‘How are your eyes?’
# 9827      Where are the parents?
# 9829      How are his pupils?’
# 9844      How's the little chap on the railings?’
# 9850      Where's this fracture, then?’
# 9872      ‘How is it different?
# 9913      Where am I?’
# 9922      How could she do the same, when he wasn't there?
# 9945      How was poor Blanche these days?
# 9963      ‘How do you do.
# 9970      ‘How are you, Lily?
# 9983      Where's Mammy?’
# 10402     How is Mick?
# 10403     Who else used to do it?
# 10410     How are things?
# 10411     Where's the dancing?
# 10458     Who is or was he incidentally?
# 10588     ‘Now, where was I?
# 10622     Where's your sense, all of you?
# 10650     How do they do that?
# 11012     ‘How could I?
# 11142     How did you do A?
# 11146     How would you do that?
# 11260     who is it then?
# 11273     Who is it?
# 11275     Who is it?
# 11295     . How did he do that then?
# 11368     Where is it?
# 11383     who's the other one?
# 11395     Who's is that, dad's suggestion?
# 11416     How are you?
# 11417     Where's the, where's the  cat book for Marge ?
# 11418     Where's the list?
# 11419     Where's where's the receipt?
# 11420     How are you then?
# 11426     Right so who's are these.
# 11434     Who's the other lady?
# 11435     Who do you have a coffee morning with?
# 11445     Who's she?
# 11450     Oh who's this Terry?
# 11452     Who's that?
# 11455     Who is it?
# 11460     Who's she then?
# 11507     Where's is erm  where's my handbag?
# 11510     Who's that from your   society?
# 11511     Who are they?
# 11533     Who is it?
# 11542     Where's that down at Debenhams?
# 11621     Oh, well where's the suit then?
# 11623     Yeah, where is Profile then?
# 11625     How is he?
# 11676     Where's that Chris then?
# 11693     Who's the camcorder and that all for the school?
# 11696     Who's this?
# 11720     Where's your toys?
# 11725     Who's are the  first?
# 11736     How  do their ballet at ?
# 11739     Who does it then?
# 11742     Who's this?
# 11748     Where was you then?
# 11758     Where's the dials?
# 11760     How are you?
# 11825     How do other faiths tackle that  reading.
# 11990     ‘How do you do, Mrs Wormwood.’
# 12047     Who is responsible for this dirty job?
# 12071     ‘How did your father die?’
# 12100     How are your ears, Eric, after your last encounter with Miss Trunchbull?’
# 12499     Where's the bathroom?"
# 12551      "Who is it?"
# 12555     Where was Helen, anyway?
# 12561     "Who is it?
# 12596      "Who's Madame Rochard?"
# 12780     Where's the five pound then?
# 12781     Who's that?
# 12790     still don't know how to do it.
# 12795     Who's that?
# 12796     Who's that?
# 12800     Who's that?
# 12801     Who is it?
# 12802     Who's that?
# 12804     Who's that?
# 12805     So how are you a
# 12856     Who is not a refugee’?
# 13520     Who was it?
# 13578     ‘How do you do?
# 13595     Who was this woman?
# 13650     ‘How are you, my vagrant daughter?’
# 13652     Who can do the worst, the most exciting things to whom.
# 13657     Where's your glass?’
# 13728     ‘How are the greens?’
# 13848     How do you rate your chances tomorrow?’
# 13894     How are things?
# 13896     How's the golf?
# 14047     Who is it?
# 14055     How are you?
# 14070     ‘How does he do it?
# 14173     How are you?
# 14188     Who is this, Wayne?
# 14191     How did the fire start?
# 14675     Who is she?’
# 14794     Where's Wally series by Martin Handford (Walker Books, from £2.99 paperback)
# 14809     Where are women in all this?
# 15166     Where's your sense?
# 15593     Who's your favourite player?
# 15871     where's your
# 15874     Where's Rob?
# 15875     Where's Rob?
# 15889     Who was that this morning?
# 15902     How can my Mum have dreadlocks on her eyebrows?
# 15947     Where were they?
# 15984     Where is she?"
# 16046      "Who is it, then?"
# 16064      "Who is it?"
# 16161     How together are they?
# 16432     How did the people in the old town feel?
# 16472     Who was his latest mistress?
# 16493     How did he do it?
# 16500     ‘How did he do it.
# 16501     How did that sonofabitch do it so quickly?’
# 16509     Where are you?
# 16545     How are you?
# 16811     Where's Silk?’
# 16818     Who's there?’
# 16925     (Who are the characters?
# 17224     how is he or she possible?
# 17373     Who's none?
# 17722     Where did Joseph and Mary flee to after the birth of Jesus?
# 18136     Where's Leicester?
# 18163     Where's there's any discret
# 18314     Who's Who in the Theatre , 11th edn., 1952;The Times , 12 July 1960; private information from Sir Hugh Wontner (son); personal knowledge.]
# 18648     Where is the body clock?
# 18684     How far is your journey?
# 18790     Where's the harm in that?’
# 18850     Where's the harm in that?’
# 19470     How could someone do such a thing?
# ...
# 420470    how's it?
# 420485    where's the baby?
# 420532    where did you do that then?
# 420559    who does he  at twelve?
# 420561    who's Farage?
# 420571    who's Toni Kroos?
# 420597    who was he with?
# 420603    who's L who is ?
# 420609    who is his brother?
# 420612    who is he? er who is ?
# 420613    who is he?
# 420616    who's that is that
# 420669    who was that guy on the on the bike the one we were ?
# 420705    who did? what you and ?
# 420745    how is she alive?
# 420799    who wants to do that on Christmas Day?
# 420832    who's the band?
# 420846    so how do you do an SOS? S O S?
# 420889    who is Stampy again?
# 420897    well how did he accidentally do that?
# 420914    how long did this Ghana fund last for?
# 420919    where is he?  guy
# 420943    who are the Lindt balls from?
# 420958    how far is the actual university from
# 420963    how did you do it?
# 421015    where is a small knife?
# 421018    where are the nice apples?
# 421020     where's that? on the tour point ferry is it?
# 421031    who were you with British Airways?
# 421061    where w well where was she was from then?
# 421073    yeah so like where where where was the band then?
# 421081    how is he today?
# 421106    who's who's the better friend?
# 421110    where's she from though?
# 421121    how was everything with erm with  this weekend?
# 421127    where is it from?
# 421128    er  how were your mum and  on Sunday?
# 421132    where's his ex-wife from?
# 421144    who's it for?
# 421190     who is this other guy?
# 421232    where's where's my room?
# 421258    how was Brazil?
# 421291    don't where's this?
# 421338     Where was I? Huh
# 421347    how is she?
# 421371    how how is it in the house? How's ?
# 421395    where are they?
# 421633    Who are the creative representatives of this movement??
# 421659    Who is the owner??
# 422587    who were more ingratiating than gracious, more personalities than persons.
# 422900    Who are the victims of the device quacks??
# 424074    Where was the driver now??
# 424164    Where are you, Henry??
# 424320    Where were you ``??
# 424501    Where was my flashlight??
# 424570    Where were they now??
# 424590    Where there is a victim, there is a killer.
# 424784    Where is everybody ``??
# 425191    How did one attach anything to a stone wall, for that matter??
# 425250    How, then, do the kinesthetic sensations function in all this??
# 426862    `` Who 's really lying ? ``
# 427063    How 's that again ?
# Name: sentence, dtype: object

# %% [markdown]
# # Last step: save as new .json

# %%
df.to_json("final_corpus.json", orient="columns")
